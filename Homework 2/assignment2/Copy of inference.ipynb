# %%
# !pip install tiktoken transformers ipdb

import ipdb

# %pdb on
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 31.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 43.2 MB/s eta 0:00:00
# ...
# Automatic pdb calling has been turned ON

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-c36f5579453e> in <cell line: 3>()
#       1 from google.colab import drive
#       2
# ----> 3 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     275             'https://research.google.com/colaboratory/faq.html#drive-timeout'
#     276         )
# --> 277       raise ValueError('mount failed' + extra_reason)
# ...

# %%
# %cd drive/MyDrive/Google/Stanford/CS\ 229S\ Systems\ for\ Machine\ learning/code/'Systems for Machine Learning'/'Homework 2'/assignment2
# Out:
# /content/drive/MyDrive/Google/Stanford/CS 229S Systems for Machine learning/code/Systems for Machine Learning/Homework 2/assignment2

# %%
import os
os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':4096:8'

# %%
# !chmod +x run.sh

# %%
# !./run.sh
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Google/Stanford/CS 229S Systems for Machine learning/code/Systems for Machine Learning/Homework 2/assignment2/sample.py", line 7, in <module>
#     import torch
#   File "/usr/local/lib/python3.10/dist-packages/torch/__init__.py", line 1818, in <module>
#     from torch import __config__ as __config__
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 879, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 975, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1074, in get_data
# KeyboardInterrupt
# ^C

# %%
# %debug

# %%
def divide_num(n):
for i in range(n,-1,-2):
  ipdb.set_trace()
  print(n%i)

x = divide_num(50)
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-1fa2b80ebec0> in <cell line: 6>()
#       4     print(n%i)
#       5
# ----> 6 x = divide_num(50)
#       7 print(x)
#
# <ipython-input-7-1fa2b80ebec0> in divide_num(n)
#       1 def divide_num(n):
#       2   for i in range(n,-1,-2):
# ----> 3     ipdb.set_trace()
#       4     print(n%i)
#       5
#
# NameError: name 'ipdb' is not defined
# > <ipython-input-7-1fa2b80ebec0>(3)divide_num()
#       1 def divide_num(n):
#       2   for i in range(n,-1,-2):
# ----> 3     ipdb.set_trace()
#       4     print(n%i)
#       5
#
# ipdb> i
# 50
# ipdb> I+!
# *** SyntaxError: invalid syntax
# ipdb> I+1
# *** NameError: name 'I' is not defined
# ipdb> i+1
# 51
# --KeyboardInterrupt--
#
# KeyboardInterrupt: Interrupted by user
